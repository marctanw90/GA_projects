# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### We are consultants hired by the U.S Department of Education, researching on which state(s) to assist in improving participation rates and/or scores for SAT and/or ACT in the United States so resources can be allocated appropriately.
#
# For this study, we will be researching if there is a score bias for households with higher or lower median income with regards to SAT/ACT scores.
#
# We will look into the following:
# Are there any correlation between SAT and ACT participation rates and scores as well as external factor?
# Are there score or participation rate bias for households with higher or lower median income?
#
# ---------------

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).
#
# As consultants for the U.S Department of Education, arising from the increase in income inequality over the recent years, we are looking into how median household incomes across the states affects SAT/ACT participation rates and scores. Having a lead in Ivy League colleges could potentially set students up for a good headstart in their working years. In turn, increasing the income inequality gap seen across the United States.
# There have been numerous studies surrounding family income and its effects on ACT scores.
#
# Past studies have also shown that students with higher family incomes tend to have had a higher ACT Composite score as compared to students who reported a lower family income. ([*read more about this here*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# Datasets which will be used for our analysis will be the following:
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`median_family_income_2019.csv`](./data/median_family_income_2019.csv): 2019 median family income
# * [`US_region_state.xlsx`](./data/US_region_state.xlsx): US states by region

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# - Increase in income inequality in the United States over the recent years. ([*source*](https://www.pewresearch.org/social-trends/2020/01/09/trends-in-income-and-wealth-inequality/#:~:text=Over%20the%20same%20period%2C%20the,in%20the%20decades%20since%201980))
#
# - How median family income affects ACT composite scores. ACT composite score by Family Income([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf))
#
# - ACT and SAT mandatory States in the United States ([*source*](https://prepmaven.com/blog/test-prep/states-require-sat-act/))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean(ls):
    result = sum(ls) / len(ls)
    return result

# %%
ls = [1.5,2,3,4,5,6,7,8,9,10]

# %%
mean(ls)
# Out:
# 5.55

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code for population SD:
def std(ls):
    var = sum((x - mean(ls))**2 for x in ls) / len(ls)
    std_dev = var ** 0.5
    return std_dev

# %%
std(ls)
# Out:
# 2.796873254189399

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def p2f(percentage):
    return float(percentage.strip('%'))/100

# %%
# Code:
p2f('7.3%')
# Out:
# 0.073

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#import data

act2019 = pd.read_csv('../data/act_2019.csv')
sat2019 = pd.read_csv('../data/sat_2019.csv')
income2019 = pd.read_csv('../data/median_family_income_2019.csv')
usregion = pd.read_excel('../data/US_region_state.xlsx')

# %%
#check through data
print(act2019.head())
print(sat2019.head())
print(income2019.head())
print(usregion.head())
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065
#                   State  Family Income
# 0  District of Columbia         106700
# 1               Alabama          62400
# 2                Alaska          83700
# 3               Arizona          70200
# 4              Arkansas          57300
#   Abbreviation       State     Region
# 0           AL     Alabama  Southeast
# 1           AK      Alaska       West
# 2           AZ     Arizona  Southwest
# ...

# %%
#check for missing values in act2019 dataset
act2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#check for missing values in sat2019 dataset
sat2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#check for missing values in income2019 dataset
income2019.isnull().sum()
# Out:
# State            0
# Family Income    0
# dtype: int64

# %%
#check for missing values in usregion dataset
usregion.isnull().sum()
# Out:
# Abbreviation    0
# State           0
# Region          0
# dtype: int64

# %%
#merge sat2019 and act2019 dataset
df= pd.merge(left = sat2019,
         right = act2019,
         on = "State")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
#  5   Participation       51 non-null     object
#  6   Composite           51 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.2+ KB

# %%
#verify results
df.head()
# Out:
#         State Participation Rate  EBRW  Math  Total Participation  Composite
# 0     Alabama                 7%   583   560   1143          100%       18.9
# 1      Alaska                41%   556   541   1097           38%       20.1
# 2     Arizona                31%   569   565   1134           73%       19.0
# 3    Arkansas                 6%   582   559   1141          100%       19.3
# 4  California                63%   534   531   1065           23%       22.6

# %%
#merge with income2019 dataset
df= pd.merge(left = df,
         right = income2019,
         on = "State")

# %%
#check entries / data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
#  5   Participation       51 non-null     object
#  6   Composite           51 non-null     float64
#  7   Family Income       51 non-null     int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 3.6+ KB

# %%
#merge with usregion dataset
df = pd.merge (left = df,
              right = usregion,
              on = 'State')

# %%
#verify
df.head()
# Out:
#         State Participation Rate  EBRW  Math  Total Participation  Composite  \
# 0     Alabama                 7%   583   560   1143          100%       18.9
# 1      Alaska                41%   556   541   1097           38%       20.1
# 2     Arizona                31%   569   565   1134           73%       19.0
# 3    Arkansas                 6%   582   559   1141          100%       19.3
# 4  California                63%   534   531   1065           23%       22.6
#
#    Family Income Abbreviation     Region
# 0          62400           AL  Southeast
# 1          83700           AK       West
# 2          70200           AZ  Southwest
# 3          57300           AR  Southeast
# 4          85300           CA       West

# %%
#dropping unwanted columns. We will be focusing on SAT Total score and ACT Composite score from the 2019 dataset available.
df.drop(['EBRW', 'Math','Abbreviation'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               50 non-null     object
#  1   Participation Rate  50 non-null     object
#  2   Total               50 non-null     int64
#  3   Participation       50 non-null     object
#  4   Composite           50 non-null     float64
#  5   Family Income       50 non-null     int64
#  6   Region              50 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 3.1+ KB

# %%
#verify
df.head()
# Out:
#         State Participation Rate  Total Participation  Composite  \
# 0     Alabama                 7%   1143          100%       18.9
# 1      Alaska                41%   1097           38%       20.1
# 2     Arizona                31%   1134           73%       19.0
# 3    Arkansas                 6%   1141          100%       19.3
# 4  California                63%   1065           23%       22.6
#
#    Family Income     Region
# 0          62400  Southeast
# 1          83700       West
# 2          70200  Southwest
# 3          57300  Southeast
# 4          85300       West

# %%
#renaming columns
df.rename (columns = {
    'State' : 'state',
    'Participation Rate': 'participation_sat',
    'Participation': 'participation_act',
    'Total' : 'sat_score',
    'Composite': 'act_score',
    'Family Income' : 'family_income',
    'Region' : 'region'}, inplace=True)

# %%
#verify
df.head()
# Out:
#         state participation_sat  sat_score participation_act  act_score  \
# 0     Alabama                7%       1143              100%       18.9
# 1      Alaska               41%       1097               38%       20.1
# 2     Arizona               31%       1134               73%       19.0
# 3    Arkansas                6%       1141              100%       19.3
# 4  California               63%       1065               23%       22.6
#
#    family_income     region
# 0          62400  Southeast
# 1          83700       West
# 2          70200  Southwest
# 3          57300  Southeast
# 4          85300       West

# %%
#Generate descriptive statistics
df.describe()
# Out:
#          sat_score  act_score  family_income
# count    50.000000  50.000000      50.000000
# mean   1115.840000  21.424000   78288.000000
# std      96.142403   2.197267   13819.368839
# min     943.000000  17.900000   53100.000000
# 25%    1049.000000  19.800000   69525.000000
# 50%    1098.500000  20.950000   76450.000000
# 75%    1215.000000  23.750000   86275.000000
# max    1284.000000  25.500000  111800.000000

# %%
# check for empty cells
df.empty
# Out:
# False

# %%
#check for Nans
df.isnull().sum()
# Out:
# state                0
# participation_sat    0
# sat_score            0
# participation_act    0
# act_score            0
# family_income        0
# region               0
# dtype: int64

# %%
#convert participation_sat from percentage to float
df['participation_sat'].map(p2f)
# Out:
# 0     0.07
# 1     0.41
# 2     0.31
# 3     0.06
# 4     0.63
# 5     1.00
# 6     1.00
# 7     1.00
# 8     1.00
# 9     0.71
# 10    0.54
# 11    1.00
# 12    1.00
# 13    0.66
# 14    0.03
# 15    0.04
# 16    0.04
# 17    0.05
# 18    0.99
# 19    0.82
# 20    0.81
# 21    1.00
# 22    0.04
# 23    0.03
# 24    0.04
# 25    0.09
# 26    0.03
# 27    0.20
# 28    0.95
# 29    0.82
# 30    0.18
# 31    0.79
# 32    0.51
# 33    0.02
# 34    0.19
# 35    0.22
# 36    0.51
# 37    0.70
# 38    1.00
# 39    0.68
# 40    0.03
# 41    0.07
# 42    0.68
# 43    0.04
# 44    0.66
# 45    0.68
# 46    0.70
# 47    0.99
# 48    0.03
# 49    0.03
# Name: participation_sat, dtype: float64

# %%
#apply to df
df['participation_sat'] = df['participation_sat'].apply(p2f)
df.head()
# Out:
#         state  participation_sat  sat_score participation_act  act_score  \
# 0     Alabama               0.07       1143              100%       18.9
# 1      Alaska               0.41       1097               38%       20.1
# 2     Arizona               0.31       1134               73%       19.0
# 3    Arkansas               0.06       1141              100%       19.3
# 4  California               0.63       1065               23%       22.6
#
#    family_income     region
# 0          62400  Southeast
# 1          83700       West
# 2          70200  Southwest
# 3          57300  Southeast
# 4          85300       West

# %%
#convert participation_act from percentage to float
df['participation_act'] = df['participation_act'].apply(p2f)
df.head()
# Out:
#         state  participation_sat  sat_score  participation_act  act_score  \
# 0     Alabama               0.07       1143               1.00       18.9
# 1      Alaska               0.41       1097               0.38       20.1
# 2     Arizona               0.31       1134               0.73       19.0
# 3    Arkansas               0.06       1141               1.00       19.3
# 4  California               0.63       1065               0.23       22.6
#
#    family_income     region
# 0          62400  Southeast
# 1          83700       West
# 2          70200  Southwest
# 3          57300  Southeast
# 4          85300       West

# %%
#verify 
print(df.shape)
df.head()
# Out:
# (50, 7)
#         state  participation_sat  sat_score  participation_act  act_score  \
# 0     Alabama               0.07       1143               1.00       18.9
# 1      Alaska               0.41       1097               0.38       20.1
# 2     Arizona               0.31       1134               0.73       19.0
# 3    Arkansas               0.06       1141               1.00       19.3
# 4  California               0.63       1065               0.23       22.6
#
#    family_income     region
# 0          62400  Southeast
# 1          83700       West
# 2          70200  Southwest
# 3          57300  Southeast
# 4          85300       West

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#summary satistics using df.describe()
df.describe()
# Out:
#        participation_sat    sat_score  participation_act  act_score  \
# count          50.000000    50.000000          50.000000  50.000000
# mean            0.481600  1115.840000           0.592000  21.424000
# std             0.386002    96.142403           0.346534   2.197267
# min             0.020000   943.000000           0.060000  17.900000
# 25%             0.052500  1049.000000           0.242500  19.800000
# 50%             0.525000  1098.500000           0.585000  20.950000
# 75%             0.817500  1215.000000           1.000000  23.750000
# max             1.000000  1284.000000           1.000000  25.500000
#
#        family_income
# count      50.000000
# mean    78288.000000
# std     13819.368839
# min     53100.000000
# 25%     69525.000000
# 50%     76450.000000
# 75%     86275.000000
# max    111800.000000

# %%
#step 2 - dictionary comprehension to apply the standard deviation function earlier

sd = {
    'participation_sat':std(df['participation_sat']),
    'participation_act' : std(df['participation_act']),
    'sat_score' : std(df['sat_score']),
    'act_score' : std(df['act_score']), 
    'family_income' : std(df['family_income'])
} 
sd
# Out:
# {'participation_sat': 0.38212228409240934,
#  'participation_act': 0.3430510166141473,
#  'sat_score': 95.17612305615312,
#  'act_score': 2.175183670405789,
#  'family_income': 13680.477184659898}

# %% [markdown]
# ### SAT participation and scores by States

# %%
#sort SAT participation rates. high to low
df.sort_values(by='participation_sat', ascending=False).head()
# Out:
#           state  participation_sat  sat_score  participation_act  act_score  \
# 21     Michigan                1.0       1003               0.19       24.4
# 5      Colorado                1.0       1024               0.27       23.8
# 6   Connecticut                1.0       1046               0.22       25.5
# 7      Delaware                1.0        985               0.13       24.1
# 8       Florida                1.0        999               0.54       20.1
#
#     family_income     region
# 21          73700    Midwest
# 5           92500       West
# 6           98300  Northeast
# 7           77200  Northeast
# 8           65800  Southeast

# %%
#sort SAT participation rates. low to high
df.sort_values(by='participation_sat', ascending=True).head()
# Out:
#            state  participation_sat  sat_score  participation_act  act_score  \
# 33  North Dakota               0.02       1263               0.96       19.9
# 49       Wyoming               0.03       1238               1.00       19.8
# 40  South Dakota               0.03       1268               0.75       21.6
# 26      Nebraska               0.03       1260               1.00       20.0
# 48     Wisconsin               0.03       1283               1.00       20.3
#
#     family_income   region
# 33          87600  Midwest
# 49          80000     West
# 40          75100  Midwest
# 26          80300  Midwest
# 48          82000  Midwest

# %%
#sort SAT scores. high to low
df.sort_values(by='sat_score', ascending=False).head()
# Out:
#            state  participation_sat  sat_score  participation_act  act_score  \
# 22     Minnesota               0.04       1284               0.95       21.4
# 48     Wisconsin               0.03       1283               1.00       20.3
# 40  South Dakota               0.03       1268               0.75       21.6
# 33  North Dakota               0.02       1263               0.96       19.9
# 26      Nebraska               0.03       1260               1.00       20.0
#
#     family_income   region
# 22          97200  Midwest
# 48          82000  Midwest
# 40          75100  Midwest
# 33          87600  Midwest
# 26          80300  Midwest

# %%
#sort SAT scores. low to high
df.sort_values(by='sat_score', ascending=True).head()
# Out:
#             state  participation_sat  sat_score  participation_act  act_score  \
# 47  West Virginia               0.99        943               0.49       20.8
# 35       Oklahoma               0.22        963               1.00       18.9
# 7        Delaware               1.00        985               0.13       24.1
# 11          Idaho               1.00        993               0.31       22.5
# 38   Rhode Island               1.00        995               0.12       24.7
#
#     family_income     region
# 47          58500  Southwest
# 35          62200  Southwest
# 7           77200  Northeast
# 11          72500       West
# 38          82300  Northeast

# %% [markdown]
# #### remarks: Highest SAT scores are prevalent in the Midwest region. Also note that the participation rate for states with the highest scores are relatively low.

# %% [markdown]
# ### ACT participation and scores by States

# %%
#sort ACT participation rates. high to low
df.sort_values(by='participation_act', ascending=False).head()
# Out:
#         state  participation_sat  sat_score  participation_act  act_score  \
# 0     Alabama               0.07       1143                1.0       18.9
# 16   Kentucky               0.04       1232                1.0       19.8
# 48  Wisconsin               0.03       1283                1.0       20.3
# 43       Utah               0.04       1230                1.0       20.3
# 41  Tennessee               0.07       1220                1.0       19.4
#
#     family_income     region
# 0           62400  Southeast
# 16          65100  Southeast
# 48          82000    Midwest
# 43          87300       West
# 41          66400  Southeast

# %%
#sort ACT participation rates. low to high
df.sort_values(by='participation_act', ascending=True).head()
# Out:
#             state  participation_sat  sat_score  participation_act  act_score  \
# 18          Maine               0.99       1013               0.06       24.3
# 38   Rhode Island               1.00        995               0.12       24.7
# 7        Delaware               1.00        985               0.13       24.1
# 28  New Hampshire               0.95       1059               0.14       25.0
# 37   Pennsylvania               0.70       1082               0.17       23.6
#
#     family_income     region
# 18          75600  Northeast
# 38          82300  Northeast
# 7           77200  Northeast
# 28         102400  Northeast
# 37          80700  Northeast

# %%
#sort ACT scores. high to low
df.sort_values(by='act_score', ascending=False).head()
# Out:
#             state  participation_sat  sat_score  participation_act  act_score  \
# 6     Connecticut               1.00       1046               0.22       25.5
# 20  Massachusetts               0.81       1120               0.21       25.5
# 28  New Hampshire               0.95       1059               0.14       25.0
# 38   Rhode Island               1.00        995               0.12       24.7
# 31       New York               0.79       1064               0.22       24.5
#
#     family_income     region
# 6           98300  Northeast
# 20         111800  Northeast
# 28         102400  Northeast
# 38          82300  Northeast
# 31          83600  Northeast

# %%
#sort ACT participation rates. low to high
df.sort_values(by='act_score', ascending=True).head()
# Out:
#              state  participation_sat  sat_score  participation_act  \
# 27          Nevada               0.20       1156               1.00
# 23     Mississippi               0.03       1237               1.00
# 39  South Carolina               0.68       1030               0.78
# 17       Louisiana               0.05       1200               1.00
# 0          Alabama               0.07       1143               1.00
#
#     act_score  family_income     region
# 27       17.9          69300       West
# 23       18.4          53100  Southeast
# 39       18.8          66700  Southeast
# 17       18.8          61300  Southeast
# 0        18.9          62400  Southeast

# %% [markdown]
# #### remarks: Highest ACT scores are from the states above. Notably, they are mostly from the Northeast region. The participation rate from these states are also noted to be lowest in the Northeast region.

# %%
#states with participation rates above average(mean) for BOTH test sorted by family income

par_abv_mean = df.loc[(df['participation_sat']>(df['participation_sat']).mean()) & (df['participation_act']>(df['participation_act']).mean())].sort_values('family_income',ascending = False)
                                                                            
par_abv_mean.head()
# Out:
#              state  participation_sat  sat_score  participation_act  \
# 10          Hawaii               0.54       1100               0.80
# 32  North Carolina               0.51       1100               1.00
# 39  South Carolina               0.68       1030               0.78
#
#     act_score  family_income     region
# 10       19.0          93300       West
# 32       19.0          68900  Southeast
# 39       18.8          66700  Southeast

# %%
#states with SAT/ACT scores above average(mean) for BOTH test sorted by family income

score_abv_mean = df.loc[(df['sat_score']>(df['sat_score']).mean()) & (df['act_score']>(df['act_score']).mean())].sort_values('family_income',ascending = False)
                                                                                             
score_abv_mean.head()
# Out:
#             state  participation_sat  sat_score  participation_act  act_score  \
# 20  Massachusetts               0.81       1120               0.21       25.5
# 45       Virginia               0.68       1119               0.21       24.0
# 14           Iowa               0.03       1244               0.66       21.6
# 40   South Dakota               0.03       1268               0.75       21.6
#
#     family_income     region
# 20         111800  Northeast
# 45          94500  Southwest
# 14          77900    Midwest
# 40          75100    Midwest

# %%
# merging both high participation rates and "smart" states into df
df2 = pd.merge(left = par_abv_mean,
         right = score_abv_mean,
         on = "state")

df2.head()
# Out:
# Empty DataFrame
# Columns: [state, participation_sat_x, sat_score_x, participation_act_x, act_score_x, family_income_x, region_x, participation_sat_y, sat_score_y, participation_act_y, act_score_y, family_income_y, region_y]
# Index: []

# %% [markdown]
# #### There are no states with participation rates for both SAT & ACT higher than average, which are also scoring above the average score for both test.

# %%
# mean family income 
(df['family_income']).mean()
# Out:
# 78288.0

# %%
#states above Median family income

rich_states = df.loc[(df['family_income']>(df['family_income']).mean())].sort_values('state',ascending = True)

rich_states.head()
# Out:
#           state  participation_sat  sat_score  participation_act  act_score  \
# 1        Alaska               0.41       1097               0.38       20.1
# 4    California               0.63       1065               0.23       22.6
# 5      Colorado               1.00       1024               0.27       23.8
# 6   Connecticut               1.00       1046               0.22       25.5
# 10       Hawaii               0.54       1100               0.80       19.0
#
#     family_income     region
# 1           83700       West
# 4           85300       West
# 5           92500       West
# 6           98300  Northeast
# 10          93300       West

# %%
#states with above average family income as well as above average SAT & ACT Scores

df3 = pd.merge(left = rich_states,
              right = score_abv_mean,
               on = 'state')
df3.head()
# Out:
#            state  participation_sat_x  sat_score_x  participation_act_x  \
# 0  Massachusetts                 0.81         1120                 0.21
# 1       Virginia                 0.68         1119                 0.21
#
#    act_score_x  family_income_x   region_x  participation_sat_y  sat_score_y  \
# 0         25.5           111800  Northeast                 0.81         1120
# 1         24.0            94500  Southwest                 0.68         1119
#
#    participation_act_y  act_score_y  family_income_y   region_y
# 0                 0.21         25.5           111800  Northeast
# 1                 0.21         24.0            94500  Southwest

# %% [markdown]
# #### only Massachusetts & Virginia have family income > avg, as well as SAT & ACT scores above average

# %%
#lets look deeper into states that have > 1 as their participation rate
df4 = df.loc[(df['participation_sat'] + df['participation_act']) > 1] 
                            
df4.info()

#35 states out of the 50 states have students which are performing both test *assuming samples are fixed within states*
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              35 non-null     object
#  1   participation_sat  35 non-null     float64
#  2   sat_score          35 non-null     int64
#  3   participation_act  35 non-null     float64
#  4   act_score          35 non-null     float64
#  5   family_income      35 non-null     int64
#  6   region             35 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.2+ KB

# %%
#lets look at how many of these 35 states have performed over the average ACT or SAT respective scores
df5 =df4[(df4['act_score'] > df4['act_score'].mean()) | (df4['sat_score'] >df4['sat_score'].mean())]

df5.head()
# Out:
#          state  participation_sat  sat_score  participation_act  act_score  \
# 0      Alabama               0.07       1143               1.00       18.9
# 2      Arizona               0.31       1134               0.73       19.0
# 3     Arkansas               0.06       1141               1.00       19.3
# 5     Colorado               1.00       1024               0.27       23.8
# 6  Connecticut               1.00       1046               0.22       25.5
#
#    family_income     region
# 0          62400  Southeast
# 2          70200  Southwest
# 3          57300  Southeast
# 5          92500       West
# 6          98300  Northeast

# %%
#histogram of SAT & ACT participation
plt.hist(df['participation_act'],label = 'ACT Participation')
plt.hist(df['participation_sat'],alpha = 0.5,label = 'SAT Participation')
plt.title('Distribution of SAT & ACT Participation Rate');
plt.ylabel('Count by States')
plt.xlabel('Participation Rate')
plt.legend(loc = 'upper right', fontsize = 10);

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(1,2, figsize = (16,15), sharey = True)

df_sorted = df.sort_values(by='participation_sat',ascending=False)
sns.barplot(y='state', x='participation_sat', data=df_sorted,color='blue',ax=ax[0])
ax[0].set_title('SAT')
ax[0].axvline((df['participation_sat']).mean(), color = 'orange',linestyle='dashed')
ax[0].set_xlabel('Participation Rate')
ax[0].invert_xaxis()

sns.barplot(y='state', x='participation_act', data=df_sorted, color='red', ax=ax[1])
ax[1].set_title('ACT')
ax[1].axvline((df['participation_act']).mean(), color = 'orange',linestyle='dashed')
ax[1].set_xlabel('Participation Rate')
ax[1].set(ylabel=None)

plt.tight_layout()
plt.show()

# %%
#horizontal bar plot of ACT & SAT participation rates by states
df[['state','participation_act','participation_sat']].sort_values('participation_act').plot(x='state',kind='barh',figsize=(15,15),ylabel='state',title='ACT and SAT participation by States');

# %% [markdown]
# ## Findings:
#
# From the analysis performed above, the following are noted:
#
# * Regions may play a part in ACT/SAT scores. Notably, highest ACT scores are mostly from the Northeast region. However, participation rates from these region's states are relatively low.
# * Likewise, highest SAT scores are prevalent in the Midwest region. Similarly, participation rates are relatively low for states with the highest SAT scores.
# * As participation rates for SAT increases, participation rates for ACT test generally decreases. (inverse correlation)
# * The higher the participation rate or either SAT or ACT test, the lower the score generally.
# * There are no states with participation rates and scores for both SAT & ACT being above the average.
# * Only Massachusetts & Virginia have family income > avg, as well as SAT & ACT scores above average. We will look further the effects of family income in the visualizations below.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# # Data Dictionary
#
# Variable | Description

# %%
df.corr()
# Out:
#                    participation_sat  sat_score  participation_act  act_score  \
# participation_sat           1.000000  -0.857615          -0.864302   0.718854
# sat_score                  -0.857615   1.000000           0.662314  -0.409969
# participation_act          -0.864302   0.662314           1.000000  -0.865062
# act_score                   0.718854  -0.409969          -0.865062   1.000000
# family_income               0.365386  -0.010989          -0.483257   0.646353
#
#                    family_income
# participation_sat       0.365386
# sat_score              -0.010989
# participation_act      -0.483257
# act_score               0.646353
# family_income           1.000000

# %%
df.describe()
# Out:
#        participation_sat    sat_score  participation_act  act_score  \
# count          50.000000    50.000000          50.000000  50.000000
# mean            0.481600  1115.840000           0.592000  21.424000
# std             0.386002    96.142403           0.346534   2.197267
# min             0.020000   943.000000           0.060000  17.900000
# 25%             0.052500  1049.000000           0.242500  19.800000
# 50%             0.525000  1098.500000           0.585000  20.950000
# 75%             0.817500  1215.000000           1.000000  23.750000
# max             1.000000  1284.000000           1.000000  25.500000
#
#        family_income
# count      50.000000
# mean    78288.000000
# std     13819.368839
# min     53100.000000
# 25%     69525.000000
# 50%     76450.000000
# 75%     86275.000000
# max    111800.000000

# %%
#step 2 - dictionary comprehension to apply the standard deviation function earlier

sd = {
    'participation_SAT':std(df['participation_sat']),
    'participation_ACT' : std(df['participation_act']),
    'sat_score' : std(df['sat_score']),
    'act_score' : std(df['act_score']), 
    'family_income' : std(df['family_income'])
} 
sd
# Out:
# {'participation_SAT': 0.38212228409240934,
#  'participation_ACT': 0.3430510166141473,
#  'sat_score': 95.17612305615312,
#  'act_score': 2.175183670405789,
#  'family_income': 13680.477184659898}

# %%
#finding the correlation and p value between score and participation rate for SAT and ACT

corr, p_value = sp.stats.pearsonr(df['participation_sat'], df['sat_score'])
corr1, p_value1 = sp.stats.pearsonr(df['participation_act'],df['act_score'])

print(f'The correlation between participation rate and score for SAT is {corr},\nThe p value is {p_value} and')
print(f'The correlation between participation rate and score for ACT is {corr1},\nThe p value is {p_value1}')
# Out:
# The correlation between participation rate and score for SAT is -0.8576154066576421,
# The p value is 1.8228239314372414e-15 and
# The correlation between participation rate and score for ACT is -0.8650615002474301,
# The p value is 5.483171934495983e-16

# %%
#finding correaltion and p value between score and family income for SAT and ACT
corr, p_value = sp.stats.pearsonr(df['sat_score'], df['family_income'])
corr1, p_value1 = sp.stats.pearsonr(df['act_score'],df['family_income'])

print(f'The correlation between SAT score and family income is {corr},\nThe p value is {p_value} and')
print(f'The correlation between ACT score and family income is {corr1},\nThe p value is {p_value1}')
# Out:
# The correlation between SAT score and family income is -0.010988723531328647,
# The p value is 0.9396267966657821 and
# The correlation between ACT score and family income is 0.6463531987031266,
# The p value is 3.975816893046671e-07

# %%
#Seaborn heatmap
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap='coolwarm');
plt.title('Heatmap of Combined Dataset', fontsize = 20);

# %%
#lets look at seaborn pairplot for a visualization 
sns.set_style('darkgrid')
g = sns.pairplot(df)
g.fig.suptitle("Pairplot" ,y=1.05);

# %%
#scatterplot to show inverse relationship between SAT&ACT participation
fig,ax = plt.subplots(nrows=1, ncols=1, figsize = (15,15))

sns.regplot( x='participation_sat',y='participation_act',data=df)
ax.set_title('SAT/ACT participation distribution', size=15)
ax.set_xlabel('Participation Rate for SAT')
ax.set_ylabel('Participation Rate for ACT');

# %% [markdown]
# Remarks: Plot above shows that as Participation rates for ACT test increase, Participation rates for SAT test tend to decrease. There is a negative correlation between participation rate for ACT and SAT test.\
# Visually, the plots are distributed at the top left and bottom right indicating students may have a bias to take either of the test but not both. (From sources cited earlier, it is noted that some states make certain test mandatory)\
# For this reason, we will then look into improving SAT / ACT scores moving forward

# %%
#scatterplot to show inverse relationship between SAT&ACT score
fig,ax = plt.subplots(nrows=1, ncols=1, figsize = (15,15))

sns.regplot( x='sat_score',y='act_score',data=df)
ax.set_title('SAT/ACT score distribution', size=15)
ax.set_xlabel('SAT Score')
ax.set_ylabel('ACT Score');

# %% [markdown]
# remarks: Likewise, from the regression line, ACT & SAT scores are inversely correlated. No plots are seen in the top right corner which indicates high scores for both SAT and ACT test.

# %%
#plotting graph to see relationship between participation rates and scores

fig,ax = plt.subplots(nrows=2, ncols=1, figsize = (16,12))
fig.suptitle('scatterplot between participation rates and scores for SAT and ACT', size=15)


sns.regplot(ax=ax[0], x='participation_sat',y='sat_score',data=df)
ax[0].set_title('SAT Distribution')
ax[0].axhline((df['sat_score']).mean(), color = 'orange',linestyle='dashed')
ax[0].set_xlabel('Participation Rate for SAT')
ax[0].set_ylabel('SAT Score')

sns.regplot(ax=ax[1],x='participation_act',y='act_score',data=df)
ax[1].set_title('ACT Distribution')
ax[1].axhline((df['act_score']).mean(), color = 'orange',linestyle='dashed')
ax[1].set_xlabel('Participation Rate for ACT')
ax[1].set_ylabel('ACT Score');

# %% [markdown]
# remarks: from the scatterplot above, it is seen that the higher the participation rate or either SAT or ACT test, the lower the score generally.

# %%
#plotting graph to see relationship between scores and family income

fig,ax = plt.subplots(nrows=2, ncols=1, figsize = (15,15))
fig.suptitle('scatterplot between SAT & ACT scores for Family Income', size=15)
colors = {'West':'lightseagreen', 'Northeast':'maroon', 'South':'lightsalmon', 'Midwest':'cornflowerblue', 'Southeast':'black'}


sns.regplot(ax=ax[0], x='sat_score',y='family_income',data=df)
ax[0].set_title('Income Distribution for SAT Score')
ax[0].axhline((df['family_income']).mean(), color = 'orange',linestyle='dashed')
ax[0].set_xlabel('SAT Score')
ax[0].set_ylabel('Family Income')

sns.regplot(ax=ax[1],x='act_score',y='family_income',data=df)
ax[1].set_title('Income Distribution for ACT Score')
ax[1].axhline((df['family_income']).mean(), color = 'orange',linestyle='dashed')
ax[1].set_xlabel('ACT Score')
ax[1].set_ylabel('Family Income');

# %% [markdown]
# remarks: From the scatterplot above, it is seen that as family income increases, ACT score increases. Whereas, for SAT scores, family income does not seem to have an impact.

# %%
#region analysis with boxplots

plt.figure(figsize = (15,15)).suptitle("Region analysis with boxplots",fontsize=20)

ax1 = plt.subplot(3,2,1)
ax1 = sns.boxplot(x=df['region'],y=df['sat_score'] ,data=df, orient="v", palette="Set1")
ax1.axhline((df['sat_score']).mean(), color = 'orange',linestyle='dashed')
ax1.set_title('SAT Score by Region')

ax2 = plt.subplot(3,2,2)
ax2 = sns.boxplot(x=df['region'],y=df['act_score'] ,data=df, orient="v", palette="Set1")
ax2.axhline((df['act_score']).mean(), color = 'orange',linestyle='dashed')
ax2.set_title('ACT Score by Region')

ax3 = plt.subplot(3,2,3)
ax3 = sns.boxplot(x=df['region'],y=df['participation_sat'] ,data=df, orient="v", palette="Set1")
ax3.axhline((df['participation_sat']).mean(), color = 'orange',linestyle='dashed')
ax3.set_title('SAT Participation by Region')

ax4 = plt.subplot(3,2,4)
ax4 = sns.boxplot(x=df['region'],y=df['participation_act'] ,data=df, orient="v", palette="Set1")
ax4.axhline((df['participation_act']).mean(), color = 'orange',linestyle='dashed')
ax4.set_title('ACT participation by Region')

ax5 = plt.subplot(3,2,5)
ax5 = sns.boxplot(x=df['region'],y=df['family_income'] ,data=df, orient="v", palette="Set1")
ax5.axhline((df['family_income']).mean(), color = 'orange',linestyle='dashed')
ax5.set_title('Income Distribution for SAT Score');

plt.tight_layout()
plt.show()

# %% [markdown]
# remarks: more notably, states in the Northeast region perform well for ACT test whilst having mostly lower participation rates. They are also wealthier amongst the other regions.
#
# lowest ACT scores are coming from the Southeast and Southwest region. Family income and ACT test scores are below the average in these regions.
#
# These regions could be suitable targets for our problem statement (increasing ACT scores in these states).

# %%
#lets dive deeper into region breakdown
df_west = df[df['region'] == 'West']
df_southeast = df[df['region'] == 'Southeast']
df_northeast = df[df['region'] == 'Northeast']
df_southwest = df[df['region'] == 'Southwest']
df_midwest = df[df['region'] == 'Midwest']

# %%
fig, ax = plt.subplots(3,2, figsize=(16, 16))
colors = {'West':'lightseagreen', 'Northeast':'maroon', 'South':'lightsalmon', 'Midwest':'cornflowerblue'}

df_west.plot(ax=ax[0][0], kind='scatter', x="family_income", y="act_score", color = 'green')
ax[0][0].set_title('West region', size = 15)
ax[0][0].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[0][0].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed')

df_southeast.plot(ax=ax[0][1], kind='scatter', x="family_income", y="act_score", color = 'red')
ax[0][1].set_title('Southeast region', size =15)
ax[0][1].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[0][1].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed')


df_northeast.plot(ax=ax[1][0], kind='scatter', x="family_income", y="act_score", color = 'blue')
ax[1][0].set_title('Northeast region',size =15)
ax[1][0].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[1][0].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed')


df_midwest.plot(ax=ax[1][1], kind='scatter', x="family_income", y="act_score",color='purple')
ax[1][1].set_title('Midwest region',size =15);
ax[1][1].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[1][1].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed')

df_southwest.plot(ax=ax[2][0], kind='scatter', x="family_income", y="act_score",color='brown')
ax[2][0].set_title('Southwest region',size =15);
ax[2][0].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[2][0].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed');

df.plot(ax=ax[2][1], kind='scatter', x="family_income", y="act_score",color='black')
ax[2][1].set_title('Overall',size =15);
ax[2][1].axhline((df['act_score']).mean(), color = 'orange', linestyle='dashed')
ax[2][1].axvline((df['family_income']).mean(), color = 'orange',linestyle='dashed');

# %% [markdown]
# remarks: Southeast and Southwest region are the poorest performers when it comes to ACT scores. These regions also house the poorer states. This is represented by plots being mostly scattered in the bottom left corner(below average ACT score & Family income)\
# Let's look into suitable states which we can help increase ACT scores

# %%
#lets filter out only the Southeast and Southwest regions. 
filter_criteria = (df.region == 'Southeast') | (df.region == 'Southwest')
df_south = df[filter_criteria]
print(df_south.shape)
df_south.head()
# Out:
# (16, 7)
#       state  participation_sat  sat_score  participation_act  act_score  \
# 0   Alabama               0.07       1143               1.00       18.9
# 2   Arizona               0.31       1134               0.73       19.0
# 3  Arkansas               0.06       1141               1.00       19.3
# 8   Florida               1.00        999               0.54       20.1
# 9   Georgia               0.71       1058               0.49       21.4
#
#    family_income     region
# 0          62400  Southeast
# 2          70200  Southwest
# 3          57300  Southeast
# 8          65800  Southeast
# 9          70800  Southeast

# %% [markdown]
# ##### Lets recap: We're looking to improve ACT rates from  Southeast & Southwest regions. (below average ACT score & family income)
# Lets pick potential states from the southeast & southwest regions based on SAT / ACT participation rates. Assuming the states with full SAT participation rates are due to state mandatory / other arrangements, we shall not be focusing on these states as students will likely be focusing on SAT test instead.

# %%
#arrange participation rate of SAT / ACT accordingly for states in the south.

sns.set_style('whitegrid')
fig, ax = plt.subplots(1,2, figsize = (15,12), sharey = True)

df_sorted = df_south.sort_values(by='participation_sat',ascending=False)
sns.barplot(y='state', x='participation_sat', data=df_sorted,color='blue',ax=ax[0])
ax[0].set_title('SAT')
ax[0].axvline((df['participation_sat']).mean(), color = 'orange',linestyle='dashed')
ax[0].set_xlabel('Participation Rate')
ax[0].invert_xaxis()

sns.barplot(y='state', x='participation_act', data=df_sorted, color='red', ax=ax[1])
ax[1].set_title('ACT')
ax[1].axvline((df['participation_act']).mean(), color = 'orange',linestyle='dashed')
ax[1].set_xlabel('Participation Rate')
ax[1].set(ylabel=None)

plt.tight_layout()
plt.show()

# %%
df_south[(df_south['act_score'])<(df_south['act_score']).mean()].sort_values('act_score',ascending = False).reset_index(drop=True)
# Out:
#             state  participation_sat  sat_score  participation_act  act_score  \
# 0       Tennessee               0.07       1220               1.00       19.4
# 1        Arkansas               0.06       1141               1.00       19.3
# 2      New Mexico               0.18       1073               0.63       19.3
# 3         Arizona               0.31       1134               0.73       19.0
# 4  North Carolina               0.51       1100               1.00       19.0
# 5         Alabama               0.07       1143               1.00       18.9
# 6        Oklahoma               0.22        963               1.00       18.9
# 7       Louisiana               0.05       1200               1.00       18.8
# 8  South Carolina               0.68       1030               0.78       18.8
# 9     Mississippi               0.03       1237               1.00       18.4
#
#    family_income     region
# 0          66400  Southeast
# 1          57300  Southeast
# ...

# %% [markdown]
# South Carolina stands out from the barplot above. From the states in the south, only South Carolina and North Carolina have participation rates above the average participation rates.
#
# As North Carolina already has a state mandate on ACT test, it would be likely that there is already educational spending on having promote better ACT scores. If the students were to focus on preparing for one exam, they might be able to attain better scores. Therefore, we'd recommend improving ACT scores in South Carolina.
#
# Futhermore, South Carolina's ACT composite score is the 2nd lowest among the Southearn states.

# %%
df[df['state']=='South Carolina'].head()
# Out:
#              state  participation_sat  sat_score  participation_act  \
# 39  South Carolina               0.68       1030               0.78
#
#     act_score  family_income     region
# 39       18.8          66700  Southeast

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on the studies above, the higher the participation rates for SAT & ACT tests, the lower the scores generally. We have learnt that there is also a positive correlationship between median family income and ACT composite scores. Students are also more likely to be biased towards a test rather than taking both SAT & ACT test concurrently.
#
# Looking into the different regions, the Southeast and Southwest regions faired the worst. All the states in those regions except for Virginia fell below the national average ACT score and national average median family income.
#
# From the barplot of the Southern regions and ACT/SAT participation rates, only two states stood out. North and South Carolina were the only two states with participation rates above the national average participation rate for both test. As North Carolina already has a state mandate on ACT participations, it would be likely that there is already an educational infastructure for ACT test. As compared to states with mandatory SAT parcipations, efforts to increase ACT scores in these states may be marginal.
#
# Futhermore, despite ACT test not being mandatory, the participation rate exceeds the national average. This could be an indicator that students signed up for the ACT test have expressed greater interest and hence may be keen in improving their scores.
#
# Therefore, the recommended state for improving ACT scores would be **South Carolina**.
#
# **Recommendations**:
#
# - Making practice resources more readily available (eg: e-learning, online resources, school libraries) for free or at subsidized rates.
# - Increase educational funding (better teaching & learning equipment/ learning facilities/ better welfare)
# - Instill ACT into school curriculum.
# - Raise standards for teachers/professors.
# - Incentivize University enrollment / acceptances for students.
# - Raise awareness through campaigns.
# - Taking racial groups, family income into consideration to moderate test scores. (China case study)
#
# **Additional data that would be helpful:**
#
# - Number of students that participated in each exam for each state for the score to be adjusted
# - Average per pupil education spending per state
# - Number of students who worked part-time for each state as this would reduce the time they have to study for the exam(s) which could result in poorer scores
# - Average time spent on studies per day
# - Social-economic statistics like race and demographics which may have an effect on the scoring amongst states.
